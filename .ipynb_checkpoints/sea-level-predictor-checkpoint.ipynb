# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
epa_sea_level = pd.read_csv('epa-sea-level.csv')

# %%
epa_sea_level = pd.read_csv("G:\\Otros ordenadores\\Mi Portátil\\Gaspar\\Analisis de datos\\Free code camp\\Sea Level Predictor\\epa-sea-level.csv"
)

epa_sea_level
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %% [markdown]
# **Scatter Plot**

# %%
# Creation of a scatter plot with measurements of the sea from CSIRO

fig, ax = plt.subplots(figsize = (12 , 6))

plt.scatter(data = epa_sea_level,
            x = "Year",
            y = "CSIRO Adjusted Sea Level",
            alpha = 0.5
            )

# %% [markdown]
# **Line Of Best Fit**

# %%
from scipy.stats import linregress

# %%
# Calculation of the slope and y-intercept of the best-fit line
slope, intercept, r_value, p_value, std_err = linregress(epa_sea_level['Year'], epa_sea_level['CSIRO Adjusted Sea Level'])

# %%
# Slope of the line
slope
# Out:
# 0.0630445840121348

# %%
# Y-intercept
intercept
# Out:
# -119.06594196773978

# %%
# Determination of the points through which the best-fit line passes
# Inclusion of the year 2050 to predict the sea level at that point

xA = pd.Series([epa_sea_level['Year'].min(),2050, 1])
yA = xA * slope + intercept

# %%
fig, ax = plt.subplots(figsize = (12 , 6))

plt.scatter(data = epa_sea_level,
            x = "Year",
            y = "CSIRO Adjusted Sea Level",
            alpha = 0.5
            )

plt.plot(x_line,
         y_line)

ax.set_ylim(bottom=-5)
# Out:
# (-5.0, 15.74640732458699)

# %%
epa_sea_level.loc[epa_sea_level['Year'] == epa_sea_level['Year'].min()]
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                       0.0          -0.952756           0.952756
#
#    NOAA Adjusted Sea Level
# 0                      NaN
